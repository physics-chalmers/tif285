# %%
# %%html
# <style>
#  table { width:80% !important; }
#  table td, th { border: 1px solid black !important;
#          text-align:center !important;
#          font-size: 20px }
# </style>
# Out:
# <style>
#  table { width:80% !important; }
#  table td, th { border: 1px solid black !important;
#          text-align:center !important;
#          font-size: 20px }
# </style>
